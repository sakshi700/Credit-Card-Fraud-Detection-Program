# %% [markdown]
# #  ***--- Credut Card Fraud Detection ---***

# %%
# import libraries
import pandas as pd

# %%
# read csv file using pandas 
import pandas as pd
data= pd.read_csv('creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score,precision_score, recall_score

# %%
X = data.drop('Class', axis=1)
y = data['Class']
print('Shape of x =', X.shape)
print('Shape of y =', y.shape)
# Out:
# Shape of x = (284807, 30)
# Shape of y = (284807,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)
print('Shape of x_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of x_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of x_train =  (227845, 30)
# Shape of y_train =  (227845,)
# Shape of x_test =  (56962, 30)
# Shape of y_test =  (56962,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score,precision_score, recall_score
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}
for name, clf in classifier.items():
    print(f"\n=========={name}===========")
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
print(f"\n Accuaracy:{accuracy_score(y_test, y_pred)}")
print(f"\n Precision:{accuracy_score(y_test, y_pred)}")
print(f"\n Recall:{accuracy_score(y_test, y_pred)}")
print(f"\n F1 Score:{accuracy_score(y_test, y_pred)}")
# Out:
# ==========Logistic Regression===========
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ==========Decision Tree Classifier===========
#
#  Accuaracy:0.9990519995786665
#
#  Precision:0.9990519995786665
#
#  Recall:0.9990519995786665
#
#  F1 Score:0.9990519995786665

# %% [markdown]
# # Null and Duplicate Values; Basic Statistics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
#  Threre are no null Values

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %% [markdown]
# # DATA VISUALAZATION

# %% [markdown]
# # line plot

# %%
import matplotlib.pyplot as plt
plt.bar(["1","0"],[1,0])
plt.xlabel('Class')
plt.ylabel('Percentage')
plt.title('Class Distibution')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.distplot(np.log(data.Amount + 0.1))
plt.title("Overall Transaction Distribution",fontsize=14)
plt.xlabel('Total')
plt.ylabel('Count')
plt.grid(False)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\1213996207.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data.Amount + 0.1))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(data['Amount'][data . Class==1])
sns.distplot(data['Amount'][data . Class==0])
plt.xlim(0,1000)
plt.xlabel('')
plt.title('Distribution of Amount',fontsize=20)
plt.legend(labels=['Fraud','Normal transaction'])
plt.gca().set_fececolor('honeydew')
plt.gcf().patch.set_facecolor('bisque')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\2534188708.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Amount'][data . Class==1])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\2534188708.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Feature Selection using coreelation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30,20))
sns.heatmap(data.corr(),cbar = 'coolwarn', annot = True, fmt = "0.2f")
for corr,column in zip(data.corr().iloc[30],data.columns):
    if abs(corr)<0.12:
        data.drop(columns = column, inplace = True)

# %%
plt.figure(figsize=(15,6))
plt.title('Heatmap of Modified DataFrame')
sns.heatmap(data.corr(), cmap='coolwarm',fmt='0.2f',annot = True)
plt.show()

# %% [markdown]
# # Distribution of Classes

# %%
data = np.array([492,284807])
mylabels=["Fraud","Normal"]
plt.pie(data,labels=mylabels)
plt.legend(title="color of credit card")
plt.show()

# %% [markdown]
# # Feature Scaling

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
data1 = data[['Time','Amount','Class']]
data1.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 data1 = data[['Time','Amount','Class']]
#       3 data1.head()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data1 = data.fillna(data.mean())

# %%
X = data.drop('Amount', axis=1)
y = data['Amount']
print('Shape of x =', X.shape)
print('Shape of y =', y.shape)
# Out:
# Shape of x = (284807, 30)
# Shape of y = (284807,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)
print('Shape of x_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of x_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of x_train =  (227845, 30)
# Shape of y_train =  (227845,)
# Shape of x_test =  (56962, 30)
# Shape of y_test =  (56962,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
sc.mean_
# Out:
# array([ 9.48160207e+04,  2.06796424e-03,  2.12193679e-03, -4.22189740e-04,
#         8.04843436e-04, -1.18553848e-03, -1.41133934e-03,  1.39360332e-04,
#         2.18319920e-03,  2.30843626e-03,  5.55751002e-04, -1.01811388e-03,
#        -2.92710163e-04, -2.03287269e-04, -1.28139135e-03, -2.10714669e-03,
#         7.52455795e-04,  2.26678704e-04,  8.41706930e-04,  5.74915781e-04,
#         1.15653962e-03, -1.47621605e-03, -2.67398251e-04, -7.57252407e-04,
#         4.62154122e-04, -2.36499182e-04, -2.63322790e-04, -7.29185316e-04,
#        -2.62023337e-04,  1.68096732e-03])

# %%
sc.scale_
# Out:
# array([4.74919888e+04, 1.95639843e+00, 1.64214131e+00, 1.52061093e+00,
#        1.41732443e+00, 1.38475877e+00, 1.33167923e+00, 1.24294289e+00,
#        1.18932069e+00, 1.09950005e+00, 1.09331673e+00, 1.02086625e+00,
#        9.98457378e-01, 9.96034375e-01, 9.58390877e-01, 9.15735814e-01,
#        8.76496959e-01, 8.52168221e-01, 8.37935469e-01, 8.14057307e-01,
#        7.70420946e-01, 7.23097345e-01, 7.24351951e-01, 6.14272305e-01,
#        6.04888743e-01, 5.21050131e-01, 4.82326135e-01, 4.07755396e-01,
#        3.31004285e-01, 4.09651275e-02])

# %%
X_train.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  227845.000000  227845.000000  227845.000000  227845.000000
# mean    94816.020747       0.002068       0.002122      -0.000422
# std     47492.093042       1.956403       1.642145       1.520614
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54153.000000      -0.920386      -0.598073      -0.892010
# 50%     84745.000000       0.020627       0.065904       0.179705
# 75%    139333.000000       1.317039       0.803005       1.026478
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  227845.000000  227845.000000  227845.000000  227845.000000
# mean        0.000805      -0.001186      -0.001411       0.000139
# std         1.417328       1.384762       1.331682       1.242946
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
X_train_sc=sc.transform(X_train)
X_test_sc=sc.transform(X_test)

# %%
X_train_sc
# Out:
# array([[ 0.92381853,  1.0996864 ,  0.05458994, ..., -0.28718694,
#         -0.24449194, -0.0410341 ],
#        [-0.88061212, -0.35586523, -0.31489125, ...,  0.33544244,
#          0.45974984, -0.0410341 ],
#        [-1.1560691 ,  0.52578063, -0.88264195, ...,  0.17241351,
#          0.06709179, -0.0410341 ],
#        ...,
#        [ 0.62317835, -0.25005001,  0.23274311, ...,  0.20937934,
#          0.40948983, -0.0410341 ],
#        [ 0.79263851,  1.01479211,  0.0844738 , ..., -0.11061214,
#         -0.22615047, -0.0410341 ],
#        [-0.11863097, -1.78688298, -2.11837527, ...,  0.88154481,
#         -0.77664996, -0.0410341 ]])

# %% [markdown]
# # Split Data

# %%
X = data.drop('Amount', axis=1)
y = data['Amount']
print('Shape of x =', X.shape)
print('Shape of y =', y.shape)
# Out:
# Shape of x = (284807, 30)
# Shape of y = (284807,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)
print('Shape of x_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of x_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of x_train =  (227845, 30)
# Shape of y_train =  (227845,)
# Shape of x_test =  (56962, 30)
# Shape of y_test =  (56962,)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-2.03469588e-05, -2.91376683e+01, -8.08334541e+01, -3.52186771e+01,
#         1.72870902e+01, -7.00819167e+01,  4.08505581e+01,  8.10730478e+01,
#        -2.20168189e+01, -1.00295659e+01, -2.30174504e+01, -4.69071808e-01,
#        -1.69489628e+00,  1.41560804e+00,  9.43066887e+00, -7.74578600e-01,
#        -3.04505524e-01,  3.00010138e+00,  1.10119754e+01, -1.74133013e+01,
#         1.09791417e+02,  3.59193810e+01, -2.23412600e+01, -4.61350536e+01,
#         2.13774665e+00, -2.40067897e+01, -1.80521996e+00,  1.86277025e+01,
#         5.45771542e+00,  4.56854356e+01])

# %%
lr.intercept_
# Out:
# 90.20291957784355

# %%
lr.predict(X_test)
# Out:
# array([226.97509895,  60.12006651,  19.32070325, ...,  32.23100473,
#        134.86868251,  79.19866603])

# %%
y_test
# Out:
# 199499    197.23
# 97815      56.96
# 171906     11.84
# 77760      38.57
# 189782     22.09
#            ...
# 273604      1.00
# 37391     100.78
# 249408     15.50
# 176671    129.00
# 66393      77.96
# Name: Amount, Length: 56962, dtype: float64

# %%
lr.score(X_test,y_test)
# Out:
# 0.8989765638781398

# %% [markdown]
# # Polynomial linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree=2)
poly_reg.fit(X_train)
X_train_poly = poly_reg.transform(X_train)
X_test_poly = poly_reg.transform(X_test)

# %%
X_train_poly.shape,X_test_poly.shape
# Out:
# ((227845, 496), (56962, 496))

# %%
lr = LinearRegression()
lr.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test_poly,y_test)
# Out:
# 0.7669251797575837

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predicted=model.predict(X_test)
model.predict_proba(X_test)
# Out:
# array([[9.99999934e-01, 6.59589682e-08],
#        [9.99218612e-01, 7.81388138e-04],
#        [9.99995110e-01, 4.89000493e-06],
#        ...,
#        [9.99998901e-01, 1.09858422e-06],
#        [9.99999302e-01, 6.97920047e-07],
#        [9.99107657e-01, 8.92343107e-04]])

# %%
model.score(X_test,y_test)
# Out:
# 0.9988939995084443

# %%
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_test.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 199499  132994.0 -0.391161 -0.679617  0.570376 -1.557790 -0.708012 -0.841936
# 97815    66397.0  1.331344 -0.424314 -0.363173 -0.495104 -0.173221 -0.173112
# 171906  120872.0 -0.391203  0.604839  0.563162 -0.812719  1.019874 -0.269028
# 77760    57198.0 -2.432331 -0.239650  1.308190 -0.546107 -0.840606 -0.222158
# 189782  128558.0  2.010146 -0.216784 -1.519050  0.761876  0.097977 -0.369543
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 199499  0.662177 -0.088338  1.328965  ...  0.424933  0.052722 -0.107316
# 97815  -0.116444 -0.097284 -1.356432  ... -0.370820 -0.779606 -1.974850
# 171906  0.943130 -0.320246  0.034404  ... -0.077936  0.174207  0.721980
# 77760  -0.754398  1.151868  0.059179  ... -0.043645  0.001081 -0.184721
# 189782 -0.193014 -0.120119  1.577719  ... -0.174151  0.132073  0.866695
#
# ...

# %%
model.coef_
# Out:
# array([[-9.41681090e-05,  4.86885793e-01, -5.65892250e-01,
#         -5.30604997e-01,  1.28925601e-01,  1.18330723e-01,
#         -3.52764440e-02,  1.52268620e-01, -2.66957128e-01,
#         -4.65916255e-01, -2.71180669e-01, -1.21218567e-01,
#         -5.34340493e-02, -3.32563454e-01, -8.64771875e-01,
#         -2.30188175e-01, -3.47672803e-01, -6.73091626e-01,
#         -8.15991549e-02,  6.89683894e-02,  3.64503410e-02,
#          1.69429374e-01,  2.11013780e-01,  2.66095294e-02,
#         -1.67512160e-02, -1.71174756e-01,  2.98769213e-02,
#         -4.27640413e-02,  5.27715480e-02, -1.47664608e-02]])

# %%
model.intercept_
# Out:
# array([-0.98742305])

# %% [markdown]
# # Logistic Regression algorithum is the best model for Credit Card Fraud Detection data set
